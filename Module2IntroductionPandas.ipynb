# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/pyCoursera/blob/master/Module2IntroductionPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Знакомство с pandas

# %%
import pandas as pd

# %%
pd.read_csv('http://meit.mgimo.ru/sites/default/files/wage1.csv')
# Out:
#       wage  educ  exper  tenure  nonwhite  female  married  numdep  smsa  \
# 0     3.10    11      2       0         0       1        0       2     1
# 1     3.24    12     22       2         0       1        1       3     1
# 2     3.00    11      2       0         0       0        0       2     0
# 3     6.00     8     44      28         0       0        1       0     1
# 4     5.30    12      7       2         0       0        1       1     0
# ..     ...   ...    ...     ...       ...     ...      ...     ...   ...
# 521  15.00    16     14       2         0       1        1       2     0
# 522   2.27    10      2       0         0       1        0       3     0
# 523   4.67    15     13      18         0       0        1       3     0
# 524  11.56    16      5       1         0       0        1       0     0
# 525   3.50    14      5       4         1       1        0       2     0
#
#      northcen  ...  trcommpu  trade  services  profserv  profocc  clerocc  \
# ...

# %%
df[:5]
# Out:
#      part   movie_name  review_id         author       date  \
# 0  top250  Блеф (1976)      17144      Come Back 2011-09-24
# 1  top250  Блеф (1976)      17139        Stasiki 2008-03-04
# 2  top250  Блеф (1976)      17137       Flashman 2007-03-04
# 3  top250  Блеф (1976)      17135  Sergio Tishin 2009-08-17
# 4  top250  Блеф (1976)      17151        Фюльгья 2009-08-20
#
#                                                title   grade3  grade10  \
# 0                             Плакали наши денежки ©     Good     10.0
# 1                                               None     Good      0.0
# 2                                               None     Good     10.0
# 3  " Черное, красное, ерунда это все. Выигрывает ...     Good      0.0
# 4                «Он хотел убежать? Да! Блеф, блеф…»  Neutral      7.0
#
#                                              content
# 0  \n"Блеф» — одна из моих самых любимых комедий....
# 1  \nАдриано Челентано продолжает радовать нас св...
# ...

# %% [markdown]
# Импорт данных из файла

# %%
data = pd.read_csv('http://meit.mgimo.ru/sites/default/files/Labour.csv')
data.head()
# Out:
#      capital  labour     output       wage
# 0   2.606563     184   9.250759  43.080307
# 1   1.323237      91   3.664310  27.780016
# 2  22.093692     426  28.781516  44.467748
# 3  10.737851      72   4.124642  39.734710
# 4   1.161365      46   2.890150  34.650709

# %%
data.head(20)
# Out:
#        capital  labour      output       wage
# 0     2.606563     184    9.250759  43.080307
# 1     1.323237      91    3.664310  27.780016
# 2    22.093692     426   28.781516  44.467748
# 3    10.737851      72    4.124642  39.734710
# 4     1.161365      46    2.890150  34.650709
# 5   276.796701    7642  480.140372  48.939782
# 6     1.678959      48    2.149454  32.458097
# 7     1.156655     108    4.140011  31.117086
# 8     0.880010      35    2.460556  35.115379
# 9     3.487317      72    3.851219  32.525225
# 10    0.526518      71    3.245624  42.703415
# 11    0.670047      29    1.718126  38.816153
# 12    2.954849      77    4.403022  26.273117
# 13    0.442732      57    2.923615  39.910290
# 14    1.142525      46    3.836346  38.902568
# 15    3.624400     188    6.526696  26.348873
# 16    0.089984       4    0.272679  24.850973
# 17    7.324654     222    3.473435  43.050238
# 18    3.614236     180    3.704220  19.716895
# ...

# %%
data.tail()
# Out:
#       capital  labour    output       wage
# 564  2.625403      20  1.424376  33.477545
# 565  1.276386      61  2.109048  26.300732
# 566  1.953869     117  6.241870  41.153979
# 567  1.318527      46  7.902237  66.720139
# 568  2.832391     161  6.804085  36.618435

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.
# Out:
#   File "<ipython-input-16-a4aa780eaf33>", line 1
#     data.
#          ^
# SyntaxError: invalid syntax

# %%
# ?pd.read_csv

# %% [markdown]
# #### Количество строк в DataFrame

# %%
len(data)
# Out:
# 569

# %%
data.shape
# Out:
# (569, 4)

# %% [markdown]
# #### Определить новый столбец

# %%
data['labour**2'] = data['labour'] ** 2
data.head()
data.shape
# Out:
# (569, 5)

# %% [markdown]
# ### Основные сведения о датафрейме

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   capital    569 non-null    float64
#  1   labour     569 non-null    int64
#  2   output     569 non-null    float64
#  3   wage       569 non-null    float64
#  4   labour**2  569 non-null    int64
# dtypes: float64(3), int64(2)
# memory usage: 22.4 KB

# %%
data.describe()
# Out:
#            capital        labour       output        wage     labour**2
# count   569.000000    569.000000   569.000000  569.000000  5.690000e+02
# mean     11.515447    201.080844    14.719225   38.632877  4.143143e+05
# std      80.518848    611.995915    62.729484   14.443246  5.384550e+06
# min       0.002231      1.000000     0.026276   11.733739  1.000000e+00
# 25%       0.983380     45.000000     2.666305   30.810818  2.025000e+03
# 50%       2.199280     86.000000     4.602574   35.982820  7.396000e+03
# 75%       6.214602    176.000000     9.742077   42.903339  3.097600e+04
# max    1786.899200  10661.000000  1279.371693  188.425081  1.136569e+08

# %% [markdown]
# ### Работа внутри таблицы

# %%
data['labour'].head()
# Out:
# 0    184
# 1     91
# 2    426
# 3     72
# 4     46
# Name: labour, dtype: int64

# %%
# или так

data.labour.head()
# Out:
# 0    184
# 1     91
# 2    426
# 3     72
# 4     46
# Name: labour, dtype: int64

# %%
type(data['labour'])
# Out:
# pandas.core.series.Series

# %%
data.head()
# Out:
#      capital  labour     output       wage  labour**2
# 0   2.606563     184   9.250759  43.080307      33856
# 1   1.323237      91   3.664310  27.780016       8281
# 2  22.093692     426  28.781516  44.467748     181476
# 3  10.737851      72   4.124642  39.734710       5184
# 4   1.161365      46   2.890150  34.650709       2116

# %%
# уникальные значения в столбце

len(data['labour'].unique())
# Out:
# 269

# %%
len(data['labour'].unique())
# Out:
# 269

# %%
data['labour'].nunique()
# Out:
# 71

# %% [markdown]
# # Фильтры

# %%
data = pd.read_csv('power.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-76-8146aa321691> in <module>
# ----> 1 data = pd.read_csv('power.csv')
#       2 data.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...

# %%
# выбрать несколько столбцов

country_stats = data.filter(items = ['country', 'quantity'])
country_stats.head()
# Out:
#    country  quantity
# 0  Austria       5.0
# 1  Austria      17.0
# 2  Belgium       0.0
# 3  Belgium       0.0
# 4  Belgium      35.0

# %%
data['country']

# %%
# или так

data[['country', 'quantity']].head()
# Out:
#    country  quantity
# 0  Austria       5.0
# 1  Austria      17.0
# 2  Belgium       0.0
# 3  Belgium       0.0
# 4  Belgium      35.0

# %% [markdown]
# ### Отфильтруем строки с потреблением выше среднего

# %%
average_level = data['quantity'].mean()
average_level
# Out:
# 184264.77005012965

# %%
'quantity > {}'.format(average_level)
# Out:
# 'quantity > 184264.77005012965'

# %%
f'quantity > {average_level}'
# Out:
# 'quantity > 184264.77005012965'

# %%
# строки с потреблением больше среднего

average_level = data['quantity'].mean()
country_stats.query('quantity > {}'.format(average_level)).head()
# Out:
#             country  quantity
# 3228  United States  367987.0
# 3229  United States  384439.0
# 3230  United States  370625.0
# 3231  United States  310909.0
# 3232  United States  335418.0

# %%
if data.quantity > average_level:

# %%
# самый популярный способ

data[ data.quantity > average_level ].head()
# Out:
#             country  year  quantity  category
# 3228  United States  2014  367987.0         2
# 3229  United States  2013  384439.0         2
# 3230  United States  2012  370625.0         2
# 3231  United States  2011  310909.0         2
# 3232  United States  2010  335418.0         2

# %%
import pandas as pd
df = pd.read_json('/Users/ruslanpepa/Desktop/kinopoisk.jsonl', lines=True)
df
# Out:
#             part             movie_name  review_id         author       date  \
# 0         top250            Блеф (1976)      17144      Come Back 2011-09-24
# 1         top250            Блеф (1976)      17139        Stasiki 2008-03-04
# 2         top250            Блеф (1976)      17137       Flashman 2007-03-04
# 3         top250            Блеф (1976)      17135  Sergio Tishin 2009-08-17
# 4         top250            Блеф (1976)      17151        Фюльгья 2009-08-20
# ...          ...                    ...        ...            ...        ...
# 36586  bottom100  Цветок дьявола (2010)      25123     bestiya163 2010-09-23
# 36587  bottom100  Цветок дьявола (2010)      25192          Молка 2010-10-02
# 36588  bottom100  Цветок дьявола (2010)      25080          jetry 2010-09-16
# 36589  bottom100  Цветок дьявола (2010)      25088         Alkort 2010-09-16
# 36590  bottom100  Цветок дьявола (2010)      25149           Флоя 2011-02-20
#
# ...

# %%
len(df['movie_name'].unique())
# Out:
# 350

# %%
# найдем все фильмы, которые вышли после 2000 года
df[ df['movie_name'].str.contains('\(20', case=False) ]['movie_name'].unique()
# Out:
# array(['Рапунцель Запутанная история (2010)',
#        'Как приручить дракона (2010)', 'Корпорация монстров (2001)',
#        'Пока не сыграл в ящик (2007)', 'ВАЛЛ·И (2008)',
#        'Апокалипсис (2006)', 'Самый быстрый «Индиан» (2005)',
#        'В диких условиях (2007)', 'Одиннадцать друзей Оушена (2001)',
#        'Шерлок Холмс Игра теней (2011)', 'Жизнь в розовом цвете (2007)',
#        'Подмена (2008)', 'Шерлок Холмс (2009)', 'Гран Торино (2008)',
#        'Игры разума (2001)', 'В погоне за счастьем (2006)',
#        'Заложница (2007)', 'Меня зовут Кхан (2010)', 'Я - Сэм (2001)',
#        'Одержимость (2004)', 'Иллюзионист (2006)',
#        'История игрушек Большой побег (2010)', 'Билли Эллиот (2000)',
#        'Пианист (2002)', 'Игра по чужим правилам (2006)', 'Артист (2011)',
#        'Догвилль (2003)', 'Терминал (2004)',
#        'Властелин колец Братство кольца (2001)',
#        'Счастливое число Слевина (2005)', 'Прислуга (2011)',
# ...

# %%
# фильтры на номер строки

df.loc[10:15]
# Out:
#       part   movie_name  review_id          author       date  \
# 10  top250  Блеф (1976)      17146       marina357 2011-01-14
# 11  top250  Блеф (1976)      17149  Годяев Дмитрий 2008-11-10
# 12  top250  Блеф (1976)      17138       max wader 2010-09-06
# 13  top250  Блеф (1976)      17136          Жёлудь 2008-09-24
# 14  top250  Блеф (1976)      17133              КД 2009-03-13
# 15  top250  Блеф (1976)      17131         kabanow 2007-03-17
#
#                                                 title grade3  grade10  \
# 10                                 Блеф по-итальянски   Good      9.0
# 11  «хук с права!приятно узнать… А это у меня Хук ...   Good      0.0
# 12                                   Спасибо, Италия!   Good      9.0
# 13  «Не надо судить о музыке, пока не закончился к...   Good      8.0
# 14                                  Все могут короли!   Good     10.0
# 15                                               None   Good      0.0
#
# ...

# %% [markdown]
# # Сортировка

# %%
# Сортировка по столбцу

df.sort_values(by='movie_name').tail(30)
# Out:
#             part                                         movie_name  \
# 7975      top250                                     Я - Сэм (2001)
# 7976      top250                                     Я - Сэм (2001)
# 7977      top250                                     Я - Сэм (2001)
# 7987      top250                                     Я - Сэм (2001)
# 7980      top250                                     Я - Сэм (2001)
# 7981      top250                                     Я - Сэм (2001)
# 7982      top250                                     Я - Сэм (2001)
# 7979      top250                                     Я - Сэм (2001)
# 33537  bottom100  Я всегда буду знать, что вы сделали прошлым ле...
# 33548  bottom100  Я всегда буду знать, что вы сделали прошлым ле...
# 33547  bottom100  Я всегда буду знать, что вы сделали прошлым ле...
# 33546  bottom100  Я всегда буду знать, что вы сделали прошлым ле...
# 33545  bottom100  Я всегда буду знать, что вы сделали прошлым ле...
# ...

# %%
# сортировка по убыванию

data.sort_values('quantity', ascending=False).head()
# Out:
#               country  year      quantity  category
# 492581  United States  2014  6.680329e+09        31
# 492267  United States  2014  6.680329e+09        31
# 492047          China  2014  5.462672e+09        31
# 492345          China  2014  5.462672e+09        31
# 122392  USSR (former)  1990  3.257000e+09        12

# %%
# сортировка по нескольким столбцам

df.sort_values(by=['movie_name', 'date', 'grade10'], ascending=[True, True, True]).head(50)
# Out:
#          part                     movie_name  review_id              author  \
# 16880  top250                     1+1 (2011)       3050         FunkyHustla
# 16860  top250                     1+1 (2011)       3082               Su-35
# 16871  top250                     1+1 (2011)       3083            Kvertoff
# 16875  top250                     1+1 (2011)       3057         NaZ LemberG
# 16877  top250                     1+1 (2011)       3065        Jessy Miller
# 16891  top250                     1+1 (2011)       3051                None
# 16879  top250                     1+1 (2011)       3059          markqwerty
# 16883  top250                     1+1 (2011)       3056               UndeR
# 16878  top250                     1+1 (2011)       3055          Ali_Mensaf
# 16864  top250                     1+1 (2011)       3068               gordy
# 16881  top250                     1+1 (2011)       3064         freemen1980
# ...
