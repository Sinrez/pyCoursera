# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinrez/pyCoursera/blob/master/stepic_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.io import imread, imshow, imsave
import urllib.request
urllib.request.urlretrieve("https://stepik.org/media/attachments/lesson/58180/tiger-color.png", "local-filename.jpg")

img=imread("local-filename.jpg")

# %%
# %matplotlib inline
from skimage.io import imread, imshow, imsave
import urllib.request
urllib.request.urlretrieve("https://stepik.org/media/attachments/lesson/58180/tiger-color.png", "local-filename.jpg")

img=imread("local-filename.jpg")
# img = imread('tiger-color-notebooks.png')
imshow(img)
# Будем работать с прямоугольной областью, содержащей нос тигра
nose = img[370:410, 350:440]
imshow(nose)
# Покрасим нос в малиновый цвет
img[370:410, 350:440] = [255, 0, 255]
imshow(img)
# Вспомним тигра с жёлтой точкой на носу
# img_yellow = imread('tiger-yellow-nose.png')
# imshow(img_yellow[370:410, 350:440])
# Правильное копирование
# img = imread('tiger-color-notebooks.png')
img_copy = img.copy()
img[370:410, 350:440] = [255, 0, 255]
imshow(img)
imshow(img_copy)

# %%
  >>> import nltk
  >>> nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize
from nltk import Text
tokens = word_tokenize('Here is some not very interesting text')
text = Text(tokens)
text
# Out:
# <Text: Here is some not very interesting text...>
